# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from scipy.spatial.distance import pdist

import numpy as np
import pandas as pd
import os
from scipy.cluster.hierarchy import fcluster, cophenet
import seaborn as sns

# %matplotlib inline
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
data = pd.read_csv('./user_data/final/EDUTECH_combined_v2.csv')
print(len(data))
# Out:
# 61

# %%
data.head()
# Out:
#    user_name         id      label user_type   type_data     type  \
# 0  Student71  Student71  Student71   Student  user_graph  student
# 1  Student14  Student14  Student14   Student  user_graph  student
# 2  Student72  Student72  Student72   Student  user_graph  student
# 3  Student83  Student83  Student83   Student  user_graph  student
# 4  Student13  Student13  Student13   Student  user_graph  student
#
#   grade_bucket age_bucket gender                        eng_fluency  \
# 0            c   18 to 24   Male                     Native speaker
# 1            d   18 to 24   Male                     Native speaker
# 2            d   25 to 34   Male  Fully fluent (non-native speaker)
# 3            d   25 to 34   Male                   Partially fluent
# 4            d   35 to 44   Male                     Native speaker
#
#               ...             degree strongcompnum closnesscentrality  \
# 0             ...                 14             4           0.595745
# 1             ...                  1             5           0.311828
# 2             ...                  5             6           0.432836
# 3             ...                  4             7           0.381579
# 4             ...                 26             4           0.538462
#
#   betweenesscentrality num_previous_OMSCS confi_avg confi_startend_diff  \
# 0            59.408311                  8       1.8                   0
# 1             0.000000                  1       1.8                   1
# 2            14.826923                  4       1.4                   1
# 3             0.000000                  2       3.0                   0
# 4           206.637526                  3       1.8                  -1
#
#   end_pace end_rigor cal_hr_expected_calc_change
# 0        4         4                          -1
# 1        5         4                          -1
# 2        4         4                          -1
# 3        4         3                           0
# 4        4         4                          -1
#
# [5 rows x 45 columns]

# %%
# scatter to guess clusters
plt.scatter(data['posts'], data['views'])
plt.show()

# %%
d2 = data.fillna(0)
d2.head()
# Out:
#    user_name         id      label user_type   type_data     type  \
# 0  Student71  Student71  Student71   Student  user_graph  student
# 1  Student14  Student14  Student14   Student  user_graph  student
# 2  Student72  Student72  Student72   Student  user_graph  student
# 3  Student83  Student83  Student83   Student  user_graph  student
# 4  Student13  Student13  Student13   Student  user_graph  student
#
#   grade_bucket age_bucket gender                        eng_fluency  \
# 0            c   18 to 24   Male                     Native speaker
# 1            d   18 to 24   Male                     Native speaker
# 2            d   25 to 34   Male  Fully fluent (non-native speaker)
# 3            d   25 to 34   Male                   Partially fluent
# 4            d   35 to 44   Male                     Native speaker
#
#               ...             degree strongcompnum closnesscentrality  \
# 0             ...                 14             4           0.595745
# 1             ...                  1             5           0.311828
# 2             ...                  5             6           0.432836
# 3             ...                  4             7           0.381579
# 4             ...                 26             4           0.538462
#
#   betweenesscentrality num_previous_OMSCS confi_avg confi_startend_diff  \
# 0            59.408311                  8       1.8                   0
# 1             0.000000                  1       1.8                   1
# 2            14.826923                  4       1.4                   1
# 3             0.000000                  2       3.0                   0
# 4           206.637526                  3       1.8                  -1
#
#   end_pace end_rigor cal_hr_expected_calc_change
# 0        4         4                          -1
# 1        5         4                          -1
# 2        4         4                          -1
# 3        4         3                           0
# 4        4         4                          -1
#
# [5 rows x 45 columns]

# %%
#record No.
d2.ix[9, :]
# Out:
# user_name                                                                Student34
# id                                                                       Student34
# label                                                                    Student34
# user_type                                                                  Student
# type_data                                                               user_graph
# type                                                                       student
# grade_bucket                                                                     d
# age_bucket                                                                25 to 34
# gender                                                                        Male
# eng_fluency                                                         Native speaker
# highest_degree                                                    Bachelors Degree
# quarter_confidence_raw                                      2 - Somewhat confident
# quarter_future_confidence_raw                                   1 - Very confident
# mid_confidence_raw                                              1 - Very confident
# mid_future_confidence_raw                                       1 - Very confident
# end_confidence_raw                                              1 - Very confident
# quarter_pace_eval_raw                                              4 - About Right
# mid_pace_eval_raw                                                  4 - About Right
# end_pace_raw                                                       4 - About Right
# quarter_rigor_eval_raw                                             4 - About Right
# mid_rigor_eval_raw                                                 4 - About Right
# end_rigor_raw                                                      4 - About Right
# start_expected_hrs                                              6-9 hours per week
# end_hr_expectation                                             9-12 hours per week
# end_hr_vary                      Yes; my time commitment varied, but not betwee...
# end_expect_project_meet                                                  6 - Agree
# end_expect_project_exceed                           4 - Neither Agree nor Disagree
# asks                                                                             3
# answers                                                                          6
# posts                                                                          404
# views                                                                          340
# days                                                                            71
# finalgrade                                                               0.4782609
# indegree                                                                        14
# outdegree                                                                       11
# degree                                                                          25
# strongcompnum                                                                    4
# closnesscentrality                                                       0.4912281
# betweenesscentrality                                                      172.2753
# num_previous_OMSCS                                                               5
# confi_avg                                                                      1.2
# confi_startend_diff                                                              1
# end_pace                                                                         4
# end_rigor                                                                        4
# cal_hr_expected_calc_change                                                      1
# Name: 9, dtype: object

# %%
X = d2.ix[:, 27:].as_matrix(columns=None)
X
# Out:
# array([[   0.,    0.,  132., ...,    4.,    4.,   -1.],
#        [   0.,    2.,   25., ...,    5.,    4.,   -1.],
#        [   2.,    0.,   49., ...,    4.,    4.,   -1.],
#        ...,
#        [   0.,    1.,   31., ...,    0.,    0.,    0.],
#        [   1.,    1.,   27., ...,    4.,    4.,    0.],
#        [   2.,    0.,   77., ...,    0.,    0.,    0.]])

# %%
####################### ITERATE THROUGH DISTNACES ################################
from sklearn.grid_search import GridSearchCV
distances = ['ward','complete','single']
for i in distances:
    Z = linkage(X, i)
    c, coph_dists = cophenet(Z, pdist(X))
    print i,c
    print "Dendogram"
    plt.figure(figsize=(30, 10))
    plt.title('EduTech {} Dendrogram'.format(i.upper()))
    plt.xlabel('Index Numbers')
    plt.ylabel('Distance')
    dendrogram(
        Z,
        leaf_rotation=90.,  
        leaf_font_size=8.,
    )
    plt.show()
    
#     print 'Truncated'
#     plt.title('Truncated Dendrogram')
#     plt.xlabel('Index Numbers')
#     plt.ylabel('Distance')
#     dendrogram(
#         Z,
#         truncate_mode='lastp',  
#         p=15,  
#         show_leaf_counts=False,  
#         leaf_rotation=90.,
#         leaf_font_size=12.,
#         show_contracted=True,  
#     )
#     plt.show()
# Out:
# ward 0.731693911823
# Dendogram
# complete 0.803584754997
# Dendogram
# single 0.711383377299
# Dendogram

# %%
Z = linkage(X, 'ward')
plt.title('Dendrogram')
plt.xlabel('Index Numbers')
plt.ylabel('Distance')
dendrogram(
    Z,
    leaf_rotation=90.,  
    leaf_font_size=8.,
)
plt.show()

# %%
max_dist = 450
clusters = fcluster(Z, max_dist, criterion='distance')
print np.unique(clusters)
print clusters
# Out:
# [1 2 3]
# [3 1 3 3 2 2 3 3 1 2 3 3 3 1 3 3 2 3 3 1 3 3 1 1 3 1 1 1 2 3 3 3 3 1 3 3 3
#  2 3 3 3 3 1 3 3 1 1 3 3 3 1 3 3 1 1 3 3 2 3 3 3]

# %%
#apply clusters and get group averages
d2['hclusters'] = clusters
d2.head()
# Out:
#    user_name         id      label user_type   type_data     type  \
# 0  Student71  Student71  Student71   Student  user_graph  student
# 1  Student14  Student14  Student14   Student  user_graph  student
# 2  Student72  Student72  Student72   Student  user_graph  student
# 3  Student83  Student83  Student83   Student  user_graph  student
# 4  Student13  Student13  Student13   Student  user_graph  student
#
#   grade_bucket age_bucket gender                        eng_fluency    ...     \
# 0            c   18 to 24   Male                     Native speaker    ...
# 1            d   18 to 24   Male                     Native speaker    ...
# 2            d   25 to 34   Male  Fully fluent (non-native speaker)    ...
# 3            d   25 to 34   Male                   Partially fluent    ...
# 4            d   35 to 44   Male                     Native speaker    ...
#
#   strongcompnum closnesscentrality betweenesscentrality num_previous_OMSCS  \
# 0             4           0.595745            59.408311                  8
# 1             5           0.311828             0.000000                  1
# 2             6           0.432836            14.826923                  4
# 3             7           0.381579             0.000000                  2
# 4             4           0.538462           206.637526                  3
#
#   confi_avg confi_startend_diff end_pace end_rigor  \
# 0       1.8                   0        4         4
# 1       1.8                   1        5         4
# 2       1.4                   1        4         4
# 3       3.0                   0        4         3
# 4       1.8                  -1        4         4
#
#   cal_hr_expected_calc_change hclusters
# 0                          -1         3
# 1                          -1         1
# 2                          -1         3
# 3                           0         3
# 4                          -1         2
#
# [5 rows x 46 columns]

# %%
#add categorical value indicators and re-do hierarchical clustering

# %%
#get list of all attributes
#list(d2.ix[:, 27:].columns)

# %%
#all vars
aggregation1 = {'id': 'count',
               'engfluency_boolean': 'count', 'male_boolean': 'count', 
              'asks': 'mean', 'answers': 'mean', 'posts': 'mean',
               'views': 'mean', 'days': 'mean',
               'finalgrade': {'finalgrade_avg':'mean', 
                              'finalgrade_min': 'min',
                              'finalgrade_max': 'max'},
               'indegree': 'mean','outdegree': 'mean', 'degree': 'mean',
               'eccentricity': 'mean','closnesscentrality':'mean',
               'harmonicclosnesscentrality': 'mean',
               'betweenesscentrality': 'mean',
               'componentnumber':'mean', 'strongcompnum':'mean',
               'modularity_class': 'mean','num_previous_OMSCS':'mean',
               'num_other_courses': 'mean','confi_avg': 'mean',
               'confi_var': 'mean','confi_startend_diff': 'mean',
               'quarter_confidence': 'mean','quarter_future_confidence': 'mean',
               'mid_confidence':'mean','mid_future_confidence': 'mean',
               'end_confidence': 'mean','pace_avg': 'mean', 'pac_var': 'mean',
               'pac_endstart_diff': 'mean','quarter_pace_eval': 'mean',
               'mid_pace_eval': 'mean', 'end_pace': 'mean','rigor_avg': 'mean',
               'rigor_var': 'mean','rigor_endstart_diff': 'mean',
               'quarter_rigor_eval': 'mean','mid_rigor_eval': 'mean',
               'end_rigor': 'mean', 'cal_hr_expected_calc_change':'mean',
               'end_expect_project_meet_num': 'mean',
               'end_expect_project_exceed_num': 'mean'}

# %%
#filtered vars
aggregation2 = {'id': 'count',
               'asks': 'mean', 'answers': 'mean', 'posts': 'mean',
               'views': 'mean', 'days': 'mean',
               'finalgrade': {'finalgrade_avg':'mean', 
                              'finalgrade_min': 'min',
                              'finalgrade_max': 'max'},
               'indegree': 'mean','outdegree': 'mean', 'degree': 'mean',
               'closnesscentrality':'mean',
               'betweenesscentrality': 'mean',
                'strongcompnum':'mean', 'num_previous_OMSCS':'mean',
               'confi_avg': 'mean','confi_startend_diff': 'mean',
                'end_pace': 'mean','end_rigor': 'mean', 
                'cal_hr_expected_calc_change':'mean'}

# %%
grp = d2.groupby('hclusters')
hcluster_grp = grp.agg(aggregation2)
hcluster_grp.to_csv('./user_data/final/edutech_hclsuter_output_v3.csv')

# %%
hcluster_grp
# Out:
#           strongcompnum confi_startend_diff  end_pace     degree      asks  \
#                    mean                mean      mean       mean      mean
# hclusters
# 1             17.250000            0.250000  3.375000   3.312500  1.812500
# 2              4.000000            0.142857  2.857143  24.000000  3.142857
# 3             13.078947            0.078947  2.947368   6.289474  1.842105
#
#                 views   indegree betweenesscentrality confi_avg       posts  \
#                  mean       mean                 mean      mean        mean
# hclusters
# 1          102.687500   1.187500             2.822791  1.537500   41.812500
# 2          289.285714  15.000000           200.823448  1.342857  184.142857
# 3          291.210526   2.789474            17.870295  1.910526   69.526316
#
#                ...         answers outdegree end_rigor closnesscentrality  \
#                ...            mean      mean      mean               mean
# hclusters      ...
# 1              ...        0.562500     2.125  3.312500           0.310376
# 2              ...        1.857143     9.000  2.857143           0.498441
# 3              ...        0.631579     3.500  2.894737           0.351710
#
#           cal_hr_expected_calc_change    id num_previous_OMSCS     finalgrade  \
#                                  mean count               mean finalgrade_min
# hclusters
# 1                           -0.250000    16           2.937500       0.347826
# 2                           -0.142857     7           4.571429       0.478261
# 3                           -0.421053    38           3.842105       0.434783
#
#
#           finalgrade_max finalgrade_avg
# hclusters
# 1               0.956522       0.608696
# 2               0.869565       0.677019
# 3               1.000000       0.697940
#
# [3 rows x 21 columns]

# %%
# plt.scatter(d2.ix[:,'finalgrade'], d2.ix[:,'views'], c=clusters, cmap='prism')
# plt.show()

# %%
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")


sns.lmplot('finalgrade', 'views', 
           data=d2, 
           fit_reg=False, 
           hue="hclusters",  
           scatter_kws={"marker": "D", 
                        "s": 100})
plt.title('EduTech Scatter Plot with Clusters')
plt.xlabel('Final Grade')
plt.ylabel('Views')

# %%
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")


sns.lmplot('confi_avg', 'betweenesscentrality', 
           data=d2, 
           fit_reg=False, 
           hue="hclusters",  
           scatter_kws={"marker": "D", 
                        "s": 100})
plt.title('EduTech Scatter Plot with Clusters')
plt.xlabel('Final Grades')
plt.ylabel('Betweeness Centrality')

# %%
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")


sns.lmplot('finalgrade', 'cal_hr_expected_calc_change', 
           data=d2, 
           fit_reg=False, 
           hue="hclusters",  
           scatter_kws={"marker": "D", 
                        "s": 100})
plt.title('EduTech Scatter Plot with Clusters')
plt.xlabel('Final Grades')
plt.ylabel('Change in Expected Hours Per Week')

# %%
#Running treees on the clustered dataset 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.preprocessing import normalize
from sklearn.feature_extraction import DictVectorizer

from sklearn import linear_model, decomposition, datasets
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV

# %%
#target values are clusters 
X2 = d2.ix[:, 27:-1].as_matrix(columns=None) #removes hclusters
Xnorm = normalize(X2)
target = d2.ix[:, -1].as_matrix(columns=None)

# %%
def tonumeric(val): 
    grade_dict = {'a': 1, 'b': 2, 'c':3, 'd': 4, 'e': 5}
    return grade_dict[val]

# %%
#target values are grade buckets, remove final grade 
# dtemp = d2.ix[:, 27:-1]
# del dtemp['finalgrade']
# X2 = dtemp.as_matrix(columns=None)
# Xnorm = normalize(X2)

# target = d2.ix[:, 'grade_bucket'].apply(lambda x: tonumeric(x)).as_matrix(columns=None)

# %%
Xnorm
# Out:
# array([[ 0.        ,  0.        ,  0.36677061, ...,  0.01111426,
#          0.01111426, -0.00277857],
#        [ 0.        ,  0.02464546,  0.3080683 , ...,  0.06161366,
#          0.04929093, -0.01232273],
#        [ 0.0057594 ,  0.        ,  0.14110532, ...,  0.0115188 ,
#          0.0115188 , -0.0028797 ],
#        ...,
#        [ 0.        ,  0.00442414,  0.13714832, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.00305943,  0.00305943,  0.08260453, ...,  0.01223771,
#          0.01223771,  0.        ],
#        [ 0.00559613,  0.        ,  0.21545097, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
trees = ExtraTreesClassifier()

# %%
#create train test split and fit to the model
x_train, x_test, y_train, y_test = train_test_split(Xnorm,target,test_size = .33, random_state = 1)
trees.fit(x_train, y_train) 

#fit tree only
# trees.fit(X2, target)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# testing
# y_pred = trees.predict(x_test)
# y_pred

cv = cross_val_score(trees, Xnorm,target, cv=5)
print cv
print np.mean(cv)
# Out:
# [ 0.92857143  1.          0.83333333  1.          0.90909091]
# 0.934199134199

# %%
importances = trees.feature_importances_
#importances_names = d2.ix[:, 27:-1].columns
importances_names = dtemp.columns


print(importances, len(importances))
print(importances_names, len(importances_names))
# Out:
# (array([ 0.07744646,  0.04717626,  0.04258565,  0.03749446,  0.11566368,
#         0.07033264,  0.04412771,  0.04207513,  0.08183821,  0.08089847,
#         0.04817705,  0.06353524,  0.03564386,  0.0559162 ,  0.05171655,
#         0.05236595,  0.05300648]), 17)
# (Index([u'asks', u'answers', u'posts', u'views', u'days', u'indegree',
#        u'outdegree', u'degree', u'strongcompnum', u'closnesscentrality',
#        u'betweenesscentrality', u'num_previous_OMSCS', u'confi_avg',
#        u'confi_startend_diff', u'end_pace', u'end_rigor',
#        u'cal_hr_expected_calc_change'],
#       dtype='object'), 17)

# %%
#graph feature importance for 
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in trees.estimators_],
             axis=0)

plt.figure()
plt.title("Edu Feature Importances Ranked")
plt.bar(range(X2.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), importances_names, rotation='vertical')
plt.xlim([-1, X.shape[1]])
plt.show()
